# %% [markdown]
# <a href="https://colab.research.google.com/github/danielphilip12/Buzzfeed/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd # import pandas library

# %%
df = pd.read_excel('/content/drive/MyDrive/Projects/Buzzfeed/data/Lesson-BuzzFeed-AB.xlsx') # import the excel file as a dataframe
df.head() # display first 5 rows of dataframe
# Out:
#                   Applied Lesson | Buzzfeed A/B Test Unnamed: 1  Unnamed: 2  \
# 0                                                NaN        NaN         NaN
# 1                                                NaN        NaN         NaN
# 2  Buzzfeed wants to test if changing the deliver...        NaN         NaN
# 3                                                NaN        NaN         NaN
# 4  Historically, 14% of people on the mailing lis...        NaN         NaN
#
#    Unnamed: 3 Time of Day  Opened  Unnamed: 6       Column  \
# 0         NaN          AM       0         NaN  Time of Day
# 1         NaN          PM       1         NaN       Opened
# 2         NaN          PM       0         NaN          NaN
# 3         NaN          AM       0         NaN          NaN
# 4         NaN          AM       0         NaN          NaN
#
#                                          Description Unnamed: 9
# 0  Time of day the user received the Buzzfeed dai...        NaN
# ...
